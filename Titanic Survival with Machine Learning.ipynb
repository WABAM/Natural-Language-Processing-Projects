# %% [markdown]
# ## Reading Datasets

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
train. head (5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Exploratory Data Analysis

# %%
train.isnull() # Checking missing values
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
 
train['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived', data=train)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
s = sns.countplot(x = 'Survived',data = train)
sizes=[]
for p in s.patches:
    height = p.get_height()
    sizes.append(height)
    s.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/len(train)*100),
            ha="center", fontsize=14)

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived', hue='Sex', data=train, palette='RdBu_r')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived', hue='Pclass', data=train, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
plt.subplot2grid((2,3),(1,0), colspan=2)
train.Age[train.Pclass == 1].plot(kind='kde')   
train.Age[train.Pclass == 2].plot(kind='kde')
train.Age[train.Pclass == 3].plot(kind='kde')
plt.xlabel(u"age")# plots an axis lable
plt.ylabel(u"density") 
plt.title(u"age distribution of different class")
plt.legend((u'class1', u'class2',u'class3'),loc='best')

# %%
sns.distplot(train['Age'].dropna(),kde=False,color='darkred',bins=40)
# Out:
# C:\Users\Selorm Hodo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age'>

# %%
sns.countplot(x='SibSp',data=train)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %%
train['Fare'].hist(color='green',bins=40,figsize=(8,4))
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='Embarked',hue='Sex',data=train);

# %%
 sns.countplot(x='Survived', hue='Embarked', data=train, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
g = sns.pairplot(data=train, hue='Survived', palette = 'seismic',
                 size=1.2,diag_kind = 'kde',diag_kws=dict(shade=True),plot_kws=dict(s=10) )
g.set(xticklabels=[])
# Out:
# C:\Users\Selorm Hodo\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
active_imports()
# Out:
# import matplotlib.pyplot as plt
# import pandas as pd
# import seaborn as sns
# ['import matplotlib.pyplot as plt',
#  'import pandas as pd',
#  'import seaborn as sns']

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# We want to fill in missing age data instead of just dropping the missing age data rows. One way to do this is by filling in the mean age of all the passengers (imputation). However we can be smarter about this and check the average age by passenger class. For example:

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='Pclass',y='Age',data=train,palette='winter')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# We can see the wealthier passengers in the higher classes tend to be older, which makes sense. We'll use these average age values to impute based on Pclass for Age.

# %%
print (train[train['Pclass']==1]['Age'].median())
print (train[train['Pclass']==2]['Age'].median())
print (train[train['Pclass']==3]['Age'].median())
# Out:
# 37.0
# 29.0
# 24.0

# %%
def impute_age(cols):
    Age = cols[0]
    Pclass = cols[1]
    
    if pd.isnull(Age):

        if Pclass == 1:
            return 37

        elif Pclass == 2:
            return 29

        else:
            return 24

    else:
        return Age

# %%
train['Age'] = train[['Age','Pclass']].apply(impute_age,axis=1)

# %%
train.drop('Cabin',axis=1,inplace=True) #drop cabin column

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
train.dropna(inplace=True)

# %% [markdown]
# Converting Categorical Features
# We'll need to convert categorical features to dummy variables using pandas! Otherwise our machine learning algorithm won't be able to directly take in those features as inputs.

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    int64
#  2   Pclass       889 non-null    int64
#  3   Name         889 non-null    object
#  4   Sex          889 non-null    object
#  5   Age          889 non-null    float64
#  6   SibSp        889 non-null    int64
#  7   Parch        889 non-null    int64
#  8   Ticket       889 non-null    object
#  9   Fare         889 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 83.3+ KB

# %%
train['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
 embark = pd.get_dummies(train['Embarked'],drop_first=True)
embark
# Out:
#      Q  S
# 0    0  1
# 1    0  0
# 2    0  1
# 3    0  1
# 4    0  1
# ..  .. ..
# 886  0  1
# 887  0  1
# 888  0  1
# 889  0  0
# 890  1  0
#
# [889 rows x 2 columns]

# %%
sex = pd.get_dummies(train['Sex'],drop_first=True)
embark = pd.get_dummies(train['Embarked'],drop_first=True)

# %%
train.drop(['Sex','Embarked','Name','Ticket'],axis=1,inplace=True)

# %%
train
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3  24.0      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [889 rows x 7 columns]

# %%
train = pd.concat([train,sex,embark],axis=1)
train
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0              1         0       3  22.0      1      0   7.2500     1  0  1
# 1              2         1       1  38.0      1      0  71.2833     0  0  0
# 2              3         1       3  26.0      0      0   7.9250     0  0  1
# 3              4         1       1  35.0      1      0  53.1000     0  0  1
# 4              5         0       3  35.0      0      0   8.0500     1  0  1
# ..           ...       ...     ...   ...    ...    ...      ...   ... .. ..
# 886          887         0       2  27.0      0      0  13.0000     1  0  1
# 887          888         1       1  19.0      0      0  30.0000     0  0  1
# 888          889         0       3  24.0      1      2  23.4500     0  0  1
# 889          890         1       1  26.0      0      0  30.0000     1  0  0
# 890          891         0       3  32.0      0      0   7.7500     1  1  0
#
# [889 rows x 10 columns]

# %% [markdown]
# ## Building a Logistic Regression model

# %%
X = train.drop('Survived',axis=1)
y = train['Survived']

# %%
train[train.columns[1:]].corr()['Survived'][:].sort_values(ascending=False).to_frame()
# Out:
#           Survived
# Survived  1.000000
# Fare      0.255290
# Parch     0.083151
# Q         0.004536
# SibSp    -0.034040
# Age      -0.052051
# S        -0.151777
# Pclass   -0.335549
# male     -0.541585

# %%
corrMatrix = train.corr()
sns.heatmap(corrMatrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
X.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0            1       3  22.0      1      0   7.2500     1  0  1
# 1            2       1  38.0      1      0  71.2833     0  0  0
# 2            3       3  26.0      0      0   7.9250     0  0  1
# 3            4       1  35.0      1      0  53.1000     0  0  1
# 4            5       3  35.0      0      0   8.0500     1  0  1

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.70, random_state = 42)

# %%
print(X_train)
# Out:
#      PassengerId  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 486          487       1  35.0      1      0  90.0000     0  0  1
# 293          294       3  24.0      0      0   8.8500     0  0  1
# 173          174       3  21.0      0      0   7.9250     1  0  1
# 450          451       2  36.0      1      2  27.7500     1  0  1
# 361          362       2  29.0      1      0  27.7208     1  0  0
# ..           ...     ...   ...    ...    ...      ...   ... .. ..
# 107          108       3  24.0      0      0   7.7750     1  0  1
# 271          272       3  25.0      0      0   0.0000     1  0  1
# 862          863       1  48.0      0      0  25.9292     0  0  1
# 436          437       3  21.0      2      2  34.3750     0  0  1
# 103          104       3  33.0      0      0   8.6542     1  0  1
#
# [622 rows x 9 columns]

# %%
print(y_train)
# Out:
# 486    1
# 293    0
# 173    0
# 450    0
# 361    0
#       ..
# 107    1
# 271    1
# 862    1
# 436    0
# 103    0
# Name: Survived, Length: 622, dtype: int64

# %%
print(X_test)
# Out:
#      PassengerId  Pclass   Age  SibSp  Parch      Fare  male  Q  S
# 281          282       3  28.0      0      0    7.8542     1  0  1
# 435          436       1  14.0      1      2  120.0000     0  0  1
# 39            40       3  14.0      1      0   11.2417     0  0  0
# 418          419       2  30.0      0      0   13.0000     1  0  1
# 585          586       1  18.0      0      2   79.6500     0  0  1
# ..           ...     ...   ...    ...    ...       ...   ... .. ..
# 454          455       3  24.0      0      0    8.0500     1  0  1
# 632          633       1  32.0      0      0   30.5000     1  0  0
# 693          694       3  25.0      0      0    7.2250     1  0  0
# 741          742       1  36.0      1      0   78.8500     1  0  1
# 430          431       1  28.0      0      0   26.5500     1  0  1
#
# [267 rows x 9 columns]

# %%
print(y_test)
# Out:
# 281    0
# 435    1
# 39     1
# 418    0
# 585    1
#       ..
# 454    0
# 632    1
# 693    0
# 741    0
# 430    1
# Name: Survived, Length: 267, dtype: int64

# %%
from sklearn.model_selection import train_test_split #for split the data
from sklearn.metrics import accuracy_score  #for accuracy_score
from sklearn.metrics import confusion_matrix #for confusion matrix

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
print(X_train)
# Out:
# [[ 0.16469724 -1.58631696  0.43287293 ... -1.39066972 -0.30833492
#    0.6157576 ]
#  [-0.57788471  0.81438657 -0.38231732 ... -1.39066972 -0.30833492
#    0.6157576 ]
#  [-1.03959369  0.81438657 -0.60464193 ...  0.719078   -0.30833492
#    0.6157576 ]
#  ...
#  [ 1.61138538 -1.58631696  1.39627959 ... -1.39066972 -0.30833492
#    0.6157576 ]
#  [-0.02768151  0.81438657 -0.60464193 ... -1.39066972 -0.30833492
#    0.6157576 ]
#  [-1.30892393  0.81438657  0.28465652 ...  0.719078   -0.30833492
#    0.6157576 ]]

# %%
print(X_test)
# Out:
# [[-0.62405561  0.81438657 -0.0858845  ...  0.719078   -0.30833492
#    0.6157576 ]
#  [-0.03152908 -1.58631696 -1.12339936 ... -1.39066972 -0.30833492
#    0.6157576 ]
#  [-1.55516873  0.81438657 -1.12339936 ... -1.39066972 -0.30833492
#   -1.62401567]
#  ...
#  [ 0.96114523  0.81438657 -0.30820911 ...  0.719078   -0.30833492
#   -1.62401567]
#  [ 1.14582882 -1.58631696  0.50698114 ...  0.719078   -0.30833492
#    0.6157576 ]
#  [-0.05076696 -1.58631696 -0.0858845  ...  0.719078   -0.30833492
#    0.6157576 ]]

# %%
pd.Series(y_train).value_counts()
# Out:
# 0    382
# 1    240
# Name: Survived, dtype: int64

# %%
pd.Series(y_test).value_counts()
# Out:
# 0    167
# 1    100
# Name: Survived, dtype: int64

# %%
print('Train Set:', X_train.shape,y_train.shape)
print('Test Set:', X_test.shape,y_test.shape)
# Out:
# Train Set: (622, 9) (622,)
# Test Set: (267, 9) (267,)

# %%
# machine learning
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(X_test)

# %%
print(classifier.predict(sc.transform([[ 282,3,28.0 ,0 ,0 ,7.8542 ,1 ,0  ,1]])))
# Out:
# [0]

# %%
print(classifier.predict(sc.transform([[586,1  ,18.0 ,0 ,2 ,79.6500 ,0 ,.0  ,1]])))
# Out:
# [1]

# %%
from sklearn.metrics import accuracy_score, recall_score #for accuracy_score and recall
from sklearn.metrics import confusion_matrix #for confusion matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
import itertools
def plot_confusion_matrix (cm, classes,
                          title = 'confusion matrix',
                          cmap = plt.cm.Blues):
    print(cm, classes = ['Survived=1','No Survived=0'], title = 'Confusion matrix')
results_Lr = accuracy_score(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='Blues')
plt.figure(figsize=(10,8))
print(f'Accuracy = {accuracy_score(y_test, y_pred)}\nRecall = {recall_score(y_test, y_pred)}\n')
# Out:
# [[138  29]
#  [ 25  75]]
# Accuracy = 0.797752808988764
# Recall = 0.75

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       163
#            1       0.75      0.72      0.74       104
#
#     accuracy                           0.80       267
#    macro avg       0.79      0.78      0.79       267
# weighted avg       0.80      0.80      0.80       267

# %%
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import roc_curve
predict_proba = classifier.predict_proba(X_test)
auc = roc_auc_score(y_test, predict_proba[::,1])
fpr, tpr, _ = roc_curve(y_test,predict_proba[:,1])

#create ROC curve
plt.plot(fpr, tpr, label='AUC='+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, recall_score #for accuracy_score and recall
from sklearn.metrics import confusion_matrix #for confusion matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
import itertools
def plot_confusion_matrix (cm, classes,
                          title = 'confusion matrix',
                          cmap = plt.cm.Blues):
    print(cm, classes = ['Survived=1','No Survived=0'], title = 'Confusion matrix')
results_rf = accuracy_score(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='Blues')
plt.figure(figsize=(10,8))
print(f'Accuracy = {accuracy_score(y_test, y_pred)}\nRecall = {recall_score(y_test, y_pred)}\n')
# Out:
# [[144  23]
#  [ 38  62]]
# Accuracy = 0.7715355805243446
# Recall = 0.62

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.83       182
#            1       0.62      0.73      0.67        85
#
#     accuracy                           0.77       267
#    macro avg       0.74      0.76      0.75       267
# weighted avg       0.79      0.77      0.78       267

# %%
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import roc_curve
predict_proba = classifier.predict_proba(X_test)
auc = roc_auc_score(y_test, predict_proba[::,1])
fpr, tpr, _ = roc_curve(y_test,predict_proba[:,1])

#create ROC curve
plt.plot(fpr, tpr, label='AUC='+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, recall_score #for accuracy_score and recall
from sklearn.metrics import confusion_matrix #for confusion matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
import itertools
def plot_confusion_matrix (cm, classes,
                          title = 'confusion matrix',
                          cmap = plt.cm.Blues):
    print(cm, classes = ['Survived=1','No Survived=0'], title = 'Confusion matrix')
results_svm = accuracy_score(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='Blues')
plt.figure(figsize=(10,8))
print(f'Accuracy = {accuracy_score(y_test, y_pred)}\nRecall = {recall_score(y_test, y_pred)}\n')
# Out:
# [[139  28]
#  [ 28  72]]
# Accuracy = 0.7902621722846442
# Recall = 0.72

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83       167
#            1       0.72      0.72      0.72       100
#
#     accuracy                           0.79       267
#    macro avg       0.78      0.78      0.78       267
# weighted avg       0.79      0.79      0.79       267

# %%
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import roc_curve
y_test_pred = classifier.decision_function(X_test)  
auc = roc_auc_score(y_test, y_test_pred)
fpr, tpr, _ = roc_curve(y_test,y_test_pred)

#create ROC curve
plt.plot(fpr, tpr, label='AUC='+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, recall_score #for accuracy_score and recall
from sklearn.metrics import confusion_matrix #for confusion matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
import itertools
def plot_confusion_matrix (cm, classes,
                          title = 'confusion matrix',
                          cmap = plt.cm.Blues):
    print(cm, classes = ['Survived=1','No Survived=0'], title = 'Confusion matrix')
results_KNN = accuracy_score(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='Blues')
plt.figure(figsize=(10,8))
print(f'Accuracy = {accuracy_score(y_test, y_pred)}\nRecall = {recall_score(y_test, y_pred)}\n')
# Out:
# [[143  24]
#  [ 30  70]]
# Accuracy = 0.797752808988764
# Recall = 0.7

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84       173
#            1       0.70      0.74      0.72        94
#
#     accuracy                           0.80       267
#    macro avg       0.78      0.79      0.78       267
# weighted avg       0.80      0.80      0.80       267

# %%
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import roc_curve
predict_proba = classifier.predict_proba(X_test)
auc = roc_auc_score(y_test, predict_proba[::,1])
fpr, tpr, _ = roc_curve(y_test,predict_proba[:,1])

#create ROC curve
plt.plot(fpr, tpr, label='AUC='+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, recall_score #for accuracy_score and recall
from sklearn.metrics import confusion_matrix #for confusion matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
import itertools
def plot_confusion_matrix (cm, classes,
                          title = 'confusion matrix',
                          cmap = plt.cm.Blues):
    print(cm, classes = ['Survived=1','No Survived=0'], title = 'Confusion matrix')
results_gnb = accuracy_score(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='Blues')
plt.figure(figsize=(10,8))
print(f'Accuracy = {accuracy_score(y_test, y_pred)}\nRecall = {recall_score(y_test, y_pred)}\n')
# Out:
# [[137  30]
#  [ 26  74]]
# Accuracy = 0.7902621722846442
# Recall = 0.74

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83       163
#            1       0.74      0.71      0.73       104
#
#     accuracy                           0.79       267
#    macro avg       0.78      0.78      0.78       267
# weighted avg       0.79      0.79      0.79       267

# %%
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import roc_curve
predict_proba = classifier.predict_proba(X_test)
auc = roc_auc_score(y_test, predict_proba[::,1])
fpr, tpr, _ = roc_curve(y_test,predict_proba[:,1])

#create ROC curve
plt.plot(fpr, tpr, label='AUC='+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, recall_score #for accuracy_score and recall
from sklearn.metrics import confusion_matrix #for confusion matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
import itertools
def plot_confusion_matrix (cm, classes,
                          title = 'confusion matrix',
                          cmap = plt.cm.Blues):
    print(cm, classes = ['Survived=1','No Survived=0'], title = 'Confusion matrix')
results_trees = accuracy_score(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='Blues')
plt.figure(figsize=(10,8))
print(f'Accuracy = {accuracy_score(y_test, y_pred)}\nRecall = {recall_score(y_test, y_pred)}\n')
# Out:
# [[132  35]
#  [ 34  66]]
# Accuracy = 0.7415730337078652
# Recall = 0.66

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.80      0.79       166
#            1       0.66      0.65      0.66       101
#
#     accuracy                           0.74       267
#    macro avg       0.73      0.72      0.72       267
# weighted avg       0.74      0.74      0.74       267

# %%
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import roc_curve
predict_proba = classifier.predict_proba(X_test)
auc = roc_auc_score(y_test, predict_proba[::,1])
fpr, tpr, _ = roc_curve(y_test,predict_proba[:,1])

#create ROC curve
plt.plot(fpr, tpr, label='AUC='+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %%
from sklearn.ensemble import AdaBoostClassifier
classifier= AdaBoostClassifier()
classifier.fit(X_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, recall_score #for accuracy_score and recall
from sklearn.metrics import confusion_matrix #for confusion matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
import itertools
def plot_confusion_matrix (cm, classes,
                          title = 'confusion matrix',
                          cmap = plt.cm.Blues):
    print(cm, classes = ['Survived=1','No Survived=0'], title = 'Confusion matrix')
results_adb = accuracy_score(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='Blues')
plt.figure(figsize=(10,8))
print(f'Accuracy = {accuracy_score(y_test, y_pred)}\nRecall = {recall_score(y_test, y_pred)}\n')
# Out:
# [[143  24]
#  [ 24  76]]
# Accuracy = 0.8202247191011236
# Recall = 0.76

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86       167
#            1       0.76      0.76      0.76       100
#
#     accuracy                           0.82       267
#    macro avg       0.81      0.81      0.81       267
# weighted avg       0.82      0.82      0.82       267

# %%
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import roc_curve
predict_proba = classifier.predict_proba(X_test)
auc = roc_auc_score(y_test, predict_proba[::,1])
fpr, tpr, _ = roc_curve(y_test,predict_proba[:,1])

#create ROC curve
plt.plot(fpr, tpr, label='AUC='+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %%
from sklearn.ensemble import GradientBoostingClassifier
classifier= GradientBoostingClassifier()
classifier.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, recall_score #for accuracy_score and recall
from sklearn.metrics import confusion_matrix #for confusion matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
import itertools
def plot_confusion_matrix (cm, classes,
                          title = 'confusion matrix',
                          cmap = plt.cm.Blues):
    print(cm, classes = ['Survived=1','No Survived=0'], title = 'Confusion matrix')
results_gbc = accuracy_score(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='Blues')
plt.figure(figsize=(10,8))
print(f'Accuracy = {accuracy_score(y_test, y_pred)}\nRecall = {recall_score(y_test, y_pred)}\n')
# Out:
# [[150  17]
#  [ 31  69]]
# Accuracy = 0.8202247191011236
# Recall = 0.69

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.83      0.86       181
#            1       0.69      0.80      0.74        86
#
#     accuracy                           0.82       267
#    macro avg       0.79      0.82      0.80       267
# weighted avg       0.83      0.82      0.82       267

# %%
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import roc_curve
predict_proba = classifier.predict_proba(X_test)
auc = roc_auc_score(y_test, predict_proba[::,1])
fpr, tpr, _ = roc_curve(y_test,predict_proba[:,1])

#create ROC curve
plt.plot(fpr, tpr, label='AUC='+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# ##Model evaluation
# ranking our evaluation of all the models to choose the best one for our problem.

# %%
Models = pd.DataFrame({
    'Model': ['Support Vector Machines', 'KNN', 'Logistic Regression', 
              'Random Forest', 'Naive Bayes', 'AdaBoostClassifier', 
              'Gradient Boost','Decision Tree'],
    'Accuracy Score': [results_svm, results_KNN, results_Lr, 
              results_rf, results_gnb, results_adb, 
              results_gbc, results_trees]})
Models.sort_values(by='Accuracy Score',ascending=False)
# Out:
#                      Model  Accuracy Score
# 5       AdaBoostClassifier        0.820225
# 6           Gradient Boost        0.820225
# 1                      KNN        0.797753
# 2      Logistic Regression        0.797753
# 0  Support Vector Machines        0.790262
# 4              Naive Bayes        0.790262
# 3            Random Forest        0.771536
# 7            Decision Tree        0.741573

# %%
data = {'Model': ['Support Vector Machines', 'KNN', 'Logistic Regression', 'Random Forest', 'Naive Bayes', 'AdaBoostClassifier', 
        'Gradient Boost','Decision Tree'],
        'AUC Score':[0.859222, 0.815689, 0.853234, 0.796796, 0.828682, 0.834521, 0.859222, 0.725211]}
df = pd.DataFrame(data) 
df = df.sort_values(by='AUC Score',ascending=False)
df
# Out:
#                      Model  AUC Score
# 0  Support Vector Machines   0.859222
# 6           Gradient Boost   0.859222
# 2      Logistic Regression   0.853234
# 5       AdaBoostClassifier   0.834521
# 4              Naive Bayes   0.828682
# 1                      KNN   0.815689
# 3            Random Forest   0.796796
# 7            Decision Tree   0.725211

# %% [markdown]
# ## By looking at all the matrices, we can say that AdaBoost and Gradient Boost classifiers has a higher chance in correctly predicting dead passengers by ACCURACY. Support Vector Machines and Gradient Boost have higer chances by AUC Score
